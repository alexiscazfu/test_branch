# %%
import pandas as pd

# %%
df = pd.read_csv("Sales_January_2019.csv")

# 1. Ventas totales por año de construcción
sales_by_year = df.groupby("Product")["Price Each"].sum().reset_index()
# Out:
#                        Product  \
# 0                 20in Monitor
# 1       27in 4K Gaming Monitor
# 2             27in FHD Monitor
# 3       34in Ultrawide Monitor
# 4        AA Batteries (4-pack)
# 5       AAA Batteries (4-pack)
# 6     Apple Airpods Headphones
# 7   Bose SoundSport Headphones
# 8                Flatscreen TV
# 9                 Google Phone
# 10                    LG Dryer
# 11          LG Washing Machine
# 12    Lightning Charging Cable
# 13          Macbook Pro Laptop
# 14                     Product
# 15             ThinkPad Laptop
# 16        USB-C Charging Cable
# 17             Vareebadd Phone
# 18            Wired Headphones
# 19                      iPhone
#
#                                            Price Each
# 0   109.99109.99109.99109.99109.99109.99109.99109....
# 1   389.99389.99389.99389.99389.99389.99389.99389....
# 2   149.99149.99149.99149.99149.99149.99149.99149....
# 3   379.99379.99379.99379.99379.99379.99379.99379....
# 4   3.843.843.843.843.843.843.843.843.843.843.843....
# 5   2.992.992.992.992.992.992.992.992.992.992.992....
# 6   1501501501501501501501501501501501501501501501...
# 7   99.9999.9999.9999.9999.9999.9999.9999.9999.999...
# 8   3003003003003003003003003003003003003003003003...
# 9   6006006006006006006006006006006006006006006006...
# 10  600.0600.0600.0600.0600.0600.0600.0600.0600.06...
# 11  600.0600.0600.0600.0600.0600.0600.0600.0600.06...
# 12  14.9514.9514.9514.9514.9514.9514.9514.9514.951...
# 13  1700170017001700170017001700170017001700170017...
# 14  Price EachPrice EachPrice EachPrice EachPrice ...
# 15  999.99999.99999.99999.99999.99999.99999.99999....
# 16  11.9511.9511.9511.9511.9511.9511.9511.9511.951...
# 17  4004004004004004004004004004004004004004004004...
# 18  11.9911.9911.9911.9911.9911.9911.9911.9911.991...
# 19  7007007007007007007007007007007007007007007007...

# %%
# Cambio de tipo de valor
df["Price Each"] = pd.to_numeric(df["Price Each"], errors = "coerce")

# 1. Ventas totales por año de construcción
sales_by_year = df.groupby("Product")["Price Each"].sum().reset_index().sort_values(by = "Price Each", ascending = False)
sales_by_year
# Out:
#                        Product  Price Each
# 13          Macbook Pro Laptop   399500.00
# 19                      iPhone   265300.00
# 15             ThinkPad Laptop   215997.84
# 9                 Google Phone   190200.00
# 1       27in 4K Gaming Monitor   121676.88
# 6     Apple Airpods Headphones   121350.00
# 3       34in Ultrawide Monitor   118936.87
# 8                Flatscreen TV    72900.00
# 7   Bose SoundSport Headphones    65593.44
# 2             27in FHD Monitor    62695.82
# 17             Vareebadd Phone    49600.00
# 11          LG Washing Machine    25200.00
# 0                 20in Monitor    23427.87
# 10                    LG Dryer    23400.00
# 12    Lightning Charging Cable    15966.60
# 16        USB-C Charging Cable    13993.45
# 18            Wired Headphones    12049.95
# 4        AA Batteries (4-pack)     3989.76
# 5       AAA Batteries (4-pack)     3235.18
# 14                     Product        0.00
